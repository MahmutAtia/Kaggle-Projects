# %%
# !pip install mrcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 51 kB 280 kB/s
# ...
#   Created wheel for mrcnn: filename=mrcnn-0.2-py3-none-any.whl size=54931 sha256=ceed30de94c07a4a1443fb3e3f8a9037980a6a9299a96bd06178ba3bde3e555f
#   Stored in directory: /root/.cache/pip/wheels/ff/1b/2e/f361d17d566062f419fcfd88697e7159c90dbb9627372914b0
# Successfully built mrcnn
# ...

# %%
import mrcnn.config
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-27d75244a8a9> in <module>
# ----> 1 import mrcnn
#
# ModuleNotFoundError: No module named 'mrcnn'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
